# %% [markdown]
# # Model multi-variabel (PART III)

# %% [markdown]
# ## Kurva Transmisi Filter

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from matplotlib_inline.backend_inline import set_matplotlib_formats
set_matplotlib_formats('retina')

import numpy as np
import matplotlib.pyplot as plt
plt.style.use(['science', 'no-latex'])

import scipy.special as sc
import pandas as pd
import pymc as pm
import arviz as az
# az.style.use("arviz-darkgrid")
import corner

import aesara
import aesara.tensor as at
from aesara.compile.ops import as_op

# %% [markdown]
# Pada contoh kasus kali ini, kita ambil kurva transmisi dari Bessel R.

# %%
df = pd.read_csv('Bessel_R-1.txt', delimiter='\t', header=None)
df.head()
# Out:
#         0   1         2
# 0  1100.0 NaN -0.006645
# 1  1099.5 NaN -0.008312
# 2  1099.0 NaN -0.006417
# 3  1098.5 NaN -0.009574
# 4  1098.0 NaN -0.006094

# %% [markdown]
# Ambil kolom yang diperlukan (dalam hal ini adalah kolom 0 dan 2), *rename*, dan hapus `NaN`

# %%
data = df[[0, 2]]
data.columns = ['wavelength','percentage']
data = data.dropna(axis=0)

data['percentage'].head()
# Out:
# 0   -0.006645
# 1   -0.008312
# 2   -0.006417
# 3   -0.009574
# 4   -0.006094
# Name: percentage, dtype: float64

# %% [markdown]
# Lakukan interpolasi dan *drop* yang mengandung `NaN`

# %%
from scipy.interpolate import interp1d

data_clean = data.dropna(axis=1)
data_clean
# Out:
#       wavelength  percentage
# 0         1100.0   -0.006645
# 1         1099.5   -0.008312
# 2         1099.0   -0.006417
# 3         1098.5   -0.009574
# 4         1098.0   -0.006094
# ...          ...         ...
# 1796       202.0    0.000249
# 1797       201.5   -0.000679
# 1798       201.0   -0.001274
# 1799       200.5   -0.000756
# 1800       200.0   -0.000807
#
# [1801 rows x 2 columns]

# %%
data_clean = data_clean.sort_values('wavelength', ignore_index=True)
data_clean
# Out:
#       wavelength  percentage
# 0          200.0   -0.000807
# 1          200.5   -0.000756
# 2          201.0   -0.001274
# 3          201.5   -0.000679
# 4          202.0    0.000249
# ...          ...         ...
# 1796      1098.0   -0.006094
# 1797      1098.5   -0.009574
# 1798      1099.0   -0.006417
# 1799      1099.5   -0.008312
# 1800      1100.0   -0.006645
#
# [1801 rows x 2 columns]

# %%
data['wavelength'] = data_clean['wavelength'].astype('float') # pastikan kolom wavelength dalam float
data['transmissivity'] = data_clean['percentage']/100.
data.head()
# Out:
#    wavelength  percentage  transmissivity
# 0       200.0   -0.006645       -0.000008
# 1       200.5   -0.008312       -0.000008
# 2       201.0   -0.006417       -0.000013
# 3       201.5   -0.009574       -0.000007
# 4       202.0   -0.006094        0.000002

# %%
plt.figure(figsize=(6,5))
x = data['wavelength']
y = data['transmissivity']
plt.plot(x, y, 'r')
plt.xlabel('Wavelength', fontsize=18)
plt.tick_params(which='major', length=10, width=1, labelsize=18)
plt.tick_params(which='minor', length=5, width=1, labelsize=18)
# plt.xticks(fontsize=14)
# plt.yticks(fontsize=14)

plt.savefig('R_transcurve.pdf', format='pdf')

plt.show()

# %% [markdown]
# Interpolasi 1D untuk titik - titik data di atas.

# %%
f_interp = interp1d(x, y, kind='cubic')

# %%
x_dense = np.linspace(500, 900, 100)
y_dense = f_interp(x_dense)

# %%
plt.figure(figsize=(8,6))
# plt.plot(x_dense, y_dense, 'r', label='Bessel R transmission curve')
plt.plot(x_dense, y_dense, 'r')
plt.xlabel('Wavelength [nm]', fontsize=18)
plt.ylabel('Transmissivity [%]', fontsize=18)
plt.tick_params(which='major', length=10, width=1, labelsize=18)
plt.tick_params(which='minor', length=5, width=1, labelsize=18)
# plt.legend(fontsize=12)
plt.savefig('r-band.pdf', format='pdf')

# %%
x2 = np.linspace(200, 1100, 1000)
y_dense2 = f_interp(x2)

# %%
plt.figure(figsize=(8,6))
plt.plot(x2, y_dense2, 'r')
plt.xlabel('Wavelength [nm]', fontsize=18)
plt.ylabel('Transmissivity [%]', fontsize=18)
plt.tick_params(which='major', length=10, width=1, labelsize=18)
plt.tick_params(which='minor', length=5, width=1, labelsize=18)

# %% [markdown]
# ## *Blackbody Curve*

# %%
from astropy.modeling.models import BlackBody
import astropy.units as u

# %%
temperature = 5800 * u.K # temperatur bintang
bandwidth = np.arange(530, 901, 10)

# x_axis = np.arange(200, 2000) * u.nm # rentang panjang gelombang yang ditinjau (nanti disesuaikan dengan bandwidth)
x_axis = np.linspace(200, 1100, 1000) * u.nm
x_axis2 = np.arange(530, 901) * u.nm
pita = bandwidth * u.nm

# %%
bb = BlackBody(temperature=temperature)
# denum = np.max(bb(x_axis)) # faktor normalisasi supaya nilai pada λ puncak maksimum 1
bb_results = bb(x_axis)
bb_results2 = bb(x_axis2)

# %%
plt.figure(figsize=(6,5))
plt.plot(x_axis, bb_results, 'g-')
# plt.plot(x_axis2, bb_results2, 'r-', lw=2)

# %%
len(x2)
# Out:
# 1000

# %% [markdown]
# ## *Blackbody Curve* II

# %%
def Planck(λ, T): 
    """
    λ: dalam cm
    T: dalam K
    """
    a = 3.7412e-5 / ((λ * 1e-7) **5) # 1e-7 adalah konversi dari nm ke cm
    b = np.exp(1.43879/(λ * 1e-7 * T)) - 1
    return a/b

# %%
def NormData(data):
    return (data - np.min(data))/(np.max(data) - np.min(data))

# %%
x_val = x2
y_val = Planck(x_val, 5800)
y_val
# Out:
# array([4.79900306e+13, 4.96075003e+13, 5.12591802e+13, 5.29451827e+13,
#        5.46656065e+13, 5.64205363e+13, 5.82100434e+13, 6.00341849e+13,
#        6.18930045e+13, 6.37865321e+13, 6.57147838e+13, 6.76777623e+13,
#        6.96754564e+13, 7.17078419e+13, 7.37748807e+13, 7.58765219e+13,
#        7.80127009e+13, 8.01833404e+13, 8.23883499e+13, 8.46276262e+13,
#        8.69010533e+13, 8.92085028e+13, 9.15498337e+13, 9.39248929e+13,
#        9.63335153e+13, 9.87755237e+13, 1.01250729e+14, 1.03758932e+14,
#        1.06299919e+14, 1.08873469e+14, 1.11479348e+14, 1.14117311e+14,
#        1.16787102e+14, 1.19488458e+14, 1.22221102e+14, 1.24984749e+14,
#        1.27779104e+14, 1.30603864e+14, 1.33458713e+14, 1.36343331e+14,
#        3.38873058e+14, 3.38174076e+14, 3.37476595e+14, 3.36780613e+14,
#        3.36086129e+14, 3.35393138e+14, 3.34701641e+14, 3.34011633e+14,
#        3.33323112e+14, 3.32636077e+14, 3.31950525e+14, 3.31266454e+14,
#        3.30583861e+14, 3.29902743e+14, 3.29223099e+14, 3.28544926e+14,
#        3.27868222e+14, 3.27192984e+14, 3.26519210e+14, 3.25846898e+14,
#        3.25176045e+14, 3.24506648e+14, 3.23838706e+14, 3.23172215e+14,
#        3.22507174e+14, 3.21843580e+14, 3.21181431e+14, 3.20520724e+14,
#        3.19861456e+14, 3.19203626e+14, 3.18547230e+14, 3.17892267e+14,
#        3.17238734e+14, 3.16586628e+14, 3.15935947e+14, 3.15286688e+14,
#        3.14638850e+14, 3.13992429e+14, 3.13347423e+14, 3.12703829e+14,
#        3.12061646e+14, 3.11420871e+14, 3.10781500e+14, 3.10143532e+14,
#        3.09506964e+14, 3.08871794e+14, 3.08238018e+14, 3.07605636e+14,
#        3.06974643e+14, 3.06345038e+14, 3.05716818e+14, 3.05089981e+14,
#        3.04464523e+14, 3.03840443e+14, 3.03217738e+14, 3.02596406e+14,
#        3.01976443e+14, 3.01357848e+14, 3.00740617e+14, 3.00124749e+14,
#        2.99510241e+14, 2.98897090e+14, 2.98285294e+14, 2.97674850e+14,
#        2.97065755e+14, 2.96458008e+14, 2.95851605e+14, 2.95246544e+14,
#        2.94642823e+14, 2.94040439e+14, 2.93439389e+14, 2.92839671e+14,
#        2.92241282e+14, 2.91644220e+14, 2.91048482e+14, 2.90454066e+14,
#        2.89860969e+14, 2.89269188e+14, 2.88678722e+14, 2.88089567e+14,
#        2.87501720e+14, 2.86915181e+14, 2.86329945e+14, 2.85746010e+14,
#        2.85163374e+14, 2.84582034e+14, 2.84001988e+14, 2.83423233e+14,
#        2.82845766e+14, 2.82269585e+14, 2.81694688e+14, 2.81121071e+14,
#        2.80548733e+14, 2.79977671e+14, 2.79407882e+14, 2.78839363e+14,
#        2.78272113e+14, 2.77706128e+14, 2.77141406e+14, 2.76577945e+14,
#        2.76015741e+14, 2.75454793e+14, 2.74895098e+14, 2.74336654e+14,
#        2.73779457e+14, 2.73223505e+14, 2.72668796e+14, 2.72115327e+14])

# %%
den = np.max(y_val)
y_fin = y_val/den
# y_fin = NormData(y_val)

# %%
plt.figure(figsize=(8,6))
plt.plot(x2, y_fin)
plt.tick_params(which='major', width=1, length=10, labelsize=18)
plt.tick_params(which='minor', width=1, length=5, labelsize=18)

# %%
bandwidth = np.arange(530, 901, 10) # rentang sesuai kurva transmisi

bandwidth
# Out:
# array([530, 540, 550, 560, 570, 580, 590, 600, 610, 620, 630, 640, 650,
#        660, 670, 680, 690, 700, 710, 720, 730, 740, 750, 760, 770, 780,
#        790, 800, 810, 820, 830, 840, 850, 860, 870, 880, 890, 900])

# %%
y_bandwidth = Planck(bandwidth, 5800)

y_fin_bandwidth = y_bandwidth/den
# y_fin_bandwidth = (y_bandwidth - np.min(y_val))/(np.max(y_val) - np.min(y_val))

# %%
plt.figure(figsize=(8,6))
plt.plot(x2, y_fin, 'k--')
plt.plot(bandwidth, y_fin_bandwidth, 'r-')
plt.xlabel('Wavelength [nm]', fontsize=18)
plt.ylabel('Normalize Flux', fontsize=18)
plt.tick_params(which='major', width=1, length=10, labelsize=16)
plt.tick_params(which='minor', width=1, length=5, labelsize=16)
plt.savefig('planck-5800.pdf', format='pdf')
# plt.savefig('planck-5800.png', dpi=150)

# %%
# x_new = np.linspace(200, 1100, 1801)
# y_new = f_interp(x2)

# %%
# x_new[1] - x_new[0]
# x_axis[1].value - x_axis[0].value
# len(x_axis)

# %%
tcurve_data = {'wavelength': x2, 'normflux': y_dense2}
r_tcurve = pd.DataFrame.from_dict(tcurve_data)

bb_data = {'wavelength': x2, 'normflux': y_fin}
bb_curve = pd.DataFrame.from_dict(bb_data)

# %%
print(len(bb_curve))
# Out:
# 1000

# %%
dx = x2[1] - x2[0]

convo = np.convolve(r_tcurve['normflux'], bb_curve['normflux'], mode='same')

# convo_fin  = convo/len(r_tcurve['normflux']) #normalized
convo_fin  = convo/len(bb_curve['normflux']) #normalized
dx
# Out:
# 0.9009009009008935

# %%
print(len(convo))
# Out:
# 1000

# %%
plt.figure(figsize=(8, 6))
plt.plot(x2, y_dense2, 'r--', label='Bessel R trans. curve')
plt.plot(x2, y_fin, 'b--', label='Blackbody curve')
plt.plot(x2, convo_fin, 'k', linewidth=2, label='Convolution result')
plt.xlabel('Wavelength [nm]', fontsize=18)
plt.ylabel('Normalize Flux', fontsize=18)
plt.tick_params(which='major', width=1, length=10, labelsize=16)
plt.tick_params(which='minor', width=1, length=5, labelsize=16)
plt.legend(fontsize=12)

# %%
conv = np.convolve(y_dense2, y_fin, mode='same') * 0.005

# %%
plt.figure(figsize=(8, 6))
plt.plot(x2, y_dense2, 'r--', label='Bessel R trans. curve')
plt.plot(x2, y_fin, 'b--', label='Blackbody curve')
plt.plot(x2, conv, 'k', linewidth=2, label='Convolution result')
plt.xlabel('Wavelength [nm]', fontsize=18)
plt.ylabel('Normalize Flux', fontsize=18)
plt.tick_params(which='major', width=1, length=10, labelsize=16)
plt.tick_params(which='minor', width=1, length=5, labelsize=16)
plt.legend(fontsize=12)

# %% [markdown]
# ## Siapkan data sintetik dan model

# %%
x_data = np.linspace(-100, 100, 500)

# %%
# -------------------------
# pre-determined variables
# -------------------------
d_moon = 374348.01497938664 # satuan km
x0 = 0.
A = 1000.
σ_true = 250.
T = 5800.

# %%
# def fresnel_monokromatik(x, x0, d, A):
#     w = (x - x0) * np.sqrt(2 / (550 * d)) * np.sqrt(1. / 1e-6) # faktor konversi ke satuan meter
#     cc, ss = sc.fresnel(w)
#     y = A * 0.5 * ((cc + 0.5)**2 + (ss + 0.5)**2)
#     return y

def fresnel_polikromatik(x, x0, d, A):
    y0 = np.zeros(len(x))
    for i in range (len(bandwidth)):
        w = (x - x0) * np.sqrt(2 / (bandwidth[i] * d)) * np.sqrt(1. / 1e-6) # faktor konversi ke satuan meter
        cc, ss = sc.fresnel(w)
        y = A * 0.5 * ((cc + 0.5)**2 + (ss + 0.5)**2)
        y_new = f_interp(bandwidth[i]) * (Planck(bandwidth[i], T)/den) * y
        y0 += y_new
    return y0

# %%
y_data = fresnel_polikromatik(x_data, x0, d_moon, A)
# y_data_mono = fresnel_monokromatik(x_data, x0, d_moon, A)
y_data = np.random.normal(y_data, scale=σ_true)

y_data_scaled = y_data / (y_data.std()*2)

# %%
plt.figure(figsize = (14,5), facecolor='w')
plt.scatter(x_data, y_data_scaled, marker='o', c='r', alpha=0.3)
# plt.plot(x_data, y_data, 'r-', lw=1)
# plt.plot(x_data, y_data_mono, 'b-', lw=1)
plt.xlabel(r'$x$', fontsize=18)
plt.ylabel('Normalized Intensity', fontsize=18)
plt.tick_params(which='major', width=1, length=10, labelsize=18)
plt.tick_params(which='minor', width=1, length=5, labelsize=18)

plt.savefig('synt-polikromatik.pdf', format='pdf')

# %%
@as_op(itypes=[at.dvector, at.dscalar, at.dscalar, at.dscalar], otypes=[at.dvector])
def t_fresnel_polikromatik(x, x0, d, A):
    y0 = np.zeros(len(x))
    for i in range (len(bandwidth)):
        w = (x - x0) * np.sqrt(2 / (bandwidth[i] * d)) * np.sqrt(1. / 1e-6) # faktor konversi ke satuan meter
        cc, ss = sc.fresnel(w)
        y = A * 0.5 * ((cc + 0.5)**2 + (ss + 0.5)**2)
        y_new = f_interp(bandwidth[i]) * (Planck(bandwidth[i], T)/den) * y
        # y_new = f_interp(bandwidth[i]) * y
        y0 += y_new
    return y0

# %%
x_shared = aesara.shared(x_data)
d_shared = aesara.shared(d_moon)

with pm.Model() as model_polikromatik:
    A = pm.Normal('A', mu=1., sigma=0.5)
    σ = pm.HalfCauchy('σ', beta=1.)
    x0 = pm.Normal('x0', mu=0., sigma=2.)
    
    μ = t_fresnel_polikromatik(x_shared, x0, d_shared, A)
    y_pred = pm.Normal('y_pred', mu=μ, sigma=σ, observed=y_data_scaled)
    
pm.model_to_graphviz(model_polikromatik)

# %%
with model_polikromatik:
    idata = pm.sample(cores=1)
    pm.sample_posterior_predictive(idata, extend_inferencedata=True)

# %%
az.plot_trace(idata)

# %%
az.summary(idata)

# %%
# chain_count =  trace.posterior.stack(sample=("chain", "draw")).σ.values.shape[0]
# y_pred_g = pm.sample_posterior_predictive(trace, samples=chain_count, model=model_polikromatik)
idata

# %%
idata_pp = idata.posterior_predictive

idata_pp_st = idata_pp.stack(sample=("chain", "draw"))

crit_l = np.percentile(idata_pp_st['y_pred'], 2.5, axis=1)  # 2.5% persentil 
crit_u = np.percentile(idata_pp_st['y_pred'], 97.5, axis=1)  # 97.5% persentil
mean_spp = np.mean(idata_pp_st['y_pred'], axis=1) # Median

# %%
plt.figure(figsize=(12,5))
plt.plot(x_data, mean_spp, linestyle='-', linewidth=1, color="#5500ff")
plt.fill_between(x_data, crit_l, crit_u, alpha=0.3, color="#00cc66")
plt.scatter(x_data, y_data_scaled, c='r', marker='o', alpha=0.2)
# plt.plot(x_data2, y_data2, 'r-', lw=1, alpha=0.5)
plt.xlim(-70, 70)
plt.xlabel(r'$x$', fontsize=18)
plt.ylabel('Normalized Intensity', fontsize=18)
plt.tick_params(which='major', width=1, length=10, labelsize=18)
plt.tick_params(which='minor', width=1, length=5, labelsize=18)

plt.tight_layout()
plt.legend(['Mean Posterior Prediction', '95% Posterior Prediction', 'Simulated Data'], loc='upper left', fontsize=16)
plt.savefig('hasil-kurvatransmisi-planck.pdf', format='pdf')
# plt.savefig('hasil-kurvatransmisi-planck.png', dpi=150)

# %%
az.plot_ppc(idata, num_pp_samples=100, kind='cumulative', figsize=(8,6), textsize=16)

# %%
az.plot_energy(idata, figsize=(8,6))
