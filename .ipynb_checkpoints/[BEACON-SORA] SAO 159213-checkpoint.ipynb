# %% [markdown]
# # Tes `SORA` dengan data HD 150366

# %%
# %config InlineBackend.figure_format = 'retina'

from sora import LightCurve, Body, Star, Observer, Occultation
import arviz as az
az.style.use('arviz-darkgrid')

import matplotlib
import matplotlib.pyplot as plt

import pandas as pd
import os

from astropy.time import Time
import astropy.units as u

import numpy as np

from skyfield.api import load

# plt.rcParams['figure.figsize'] = (12,5)

pd.set_option('display.float_format',  '{:}'.format)
# Out:
# SORA version: 0.2.1

# %%
df = pd.read_csv('hd150366.csv', sep=',')
df.tail()
# Out:
#       FrameNum            timeInfo  signal-obj  signal-track  appsum-obj  \
# 3996    8996.0  [14:05:01.2781215]      -806.0       46116.0    450960.0
# 3997    8997.0  [14:05:01.2882213]     -6263.0       35139.0    448256.0
# 3998    8998.0  [14:05:01.2983211]      4697.0       31276.0    457328.0
# 3999    8999.0  [14:05:01.3084209]     -4485.0       41766.0    449392.0
# 4000    9000.0  [14:05:01.3185207]      4060.0       37455.0    457472.0
#
#       avgbkg-obj  stdbkg-obj  nmaskpx-obj  maxpx-obj  xcentroid-obj  \
# 3996     12209.9     3272.62          -37      23856          383.0
# 3997     12284.3     3266.79          -37      23536          383.0
# 3998    12233.27     3247.79          -37      24624          383.0
# 3999    12266.96     3293.02          -37      23536          383.0
# 4000    12254.37     3286.77          -37      23376          383.0
#
#       ycentroid-obj  appsum-track  avgbkg-track  stdbkg-track  nmaskpx-track  \
# 3996          425.0      438272.0      10598.81        888.95            -37
# 3997          425.0      427312.0      10599.27        903.31            -37
# 3998          425.0      426560.0      10683.35        905.43            -37
# 3999          425.0      433968.0      10600.04        896.74            -37
# 4000          425.0      432864.0      10686.73        900.28            -37
#
#       maxpx-track  xcentroid-track  ycentroid-track
# 3996        19200            205.0            152.0
# 3997        15072            205.0            152.0
# 3998        15520            205.0            152.0
# 3999        15456            205.0            152.0
# 4000        18368            205.0            152.0

# %%
# hilangkan karakter [ dan ] dari data
df['timeInfo'] = df['timeInfo'].map((lambda x: x.lstrip('[').rstrip(']')))

# ubah ke format waktu dan ambil tanggal dan jamnya
df['timeInfo'] = pd.to_datetime(df['timeInfo'])

df.tail()
# Out:
#       FrameNum                   timeInfo  signal-obj  signal-track  \
# 3996    8996.0 2022-08-09 14:05:01.278121      -806.0       46116.0
# 3997    8997.0 2022-08-09 14:05:01.288221     -6263.0       35139.0
# 3998    8998.0 2022-08-09 14:05:01.298321      4697.0       31276.0
# 3999    8999.0 2022-08-09 14:05:01.308420     -4485.0       41766.0
# 4000    9000.0 2022-08-09 14:05:01.318520      4060.0       37455.0
#
#       appsum-obj  avgbkg-obj  stdbkg-obj  nmaskpx-obj  maxpx-obj  \
# 3996    450960.0     12209.9     3272.62          -37      23856
# 3997    448256.0     12284.3     3266.79          -37      23536
# 3998    457328.0    12233.27     3247.79          -37      24624
# 3999    449392.0    12266.96     3293.02          -37      23536
# 4000    457472.0    12254.37     3286.77          -37      23376
#
#       xcentroid-obj  ycentroid-obj  appsum-track  avgbkg-track  stdbkg-track  \
# 3996          383.0          425.0      438272.0      10598.81        888.95
# 3997          383.0          425.0      427312.0      10599.27        903.31
# 3998          383.0          425.0      426560.0      10683.35        905.43
# 3999          383.0          425.0      433968.0      10600.04        896.74
# 4000          383.0          425.0      432864.0      10686.73        900.28
#
#       nmaskpx-track  maxpx-track  xcentroid-track  ycentroid-track
# 3996            -37        19200            205.0            152.0
# 3997            -37        15072            205.0            152.0
# 3998            -37        15520            205.0            152.0
# 3999            -37        15456            205.0            152.0
# 4000            -37        18368            205.0            152.0

# %%
data = df[['FrameNum','timeInfo','signal-obj']]
data.columns = ['Frame','Time', 'Value']
data.tail()
# Out:
#       Frame                       Time   Value
# 3996 8996.0 2022-08-09 14:05:01.278121  -806.0
# 3997 8997.0 2022-08-09 14:05:01.288221 -6263.0
# 3998 8998.0 2022-08-09 14:05:01.298321  4697.0
# 3999 8999.0 2022-08-09 14:05:01.308420 -4485.0
# 4000 9000.0 2022-08-09 14:05:01.318520  4060.0

# %%
data_cp = data.copy()

data_cp['JD'] = Time(data_cp['Time']).jd

data_cp['frac_JD'] = data_cp['JD'] - np.floor(data_cp['JD']).astype(int)
data_cp
# Out:
#       Frame                       Time    Value                 JD  \
# 0    5000.0 2022-08-09 14:04:20.919734 420288.0 2459801.0863532377
# 1    5001.0 2022-08-09 14:04:20.929834 464140.0 2459801.0863533546
# 2    5002.0 2022-08-09 14:04:20.939934 492350.0 2459801.0863534715
# 3    5003.0 2022-08-09 14:04:20.950033 397106.0 2459801.0863535884
# 4    5004.0 2022-08-09 14:04:20.960133 380007.0 2459801.0863537053
# ...     ...                        ...      ...                ...
# 3996 8996.0 2022-08-09 14:05:01.278121   -806.0 2459801.0868203486
# 3997 8997.0 2022-08-09 14:05:01.288221  -6263.0 2459801.0868204655
# 3998 8998.0 2022-08-09 14:05:01.298321   4697.0 2459801.0868205824
# 3999 8999.0 2022-08-09 14:05:01.308420  -4485.0 2459801.0868206993
# 4000 9000.0 2022-08-09 14:05:01.318520   4060.0  2459801.086820816
#
#                  frac_JD
# 0    0.08635323774069548
# 1    0.08635335462167859
# 2     0.0863534715026617
# 3    0.08635358838364482
# 4    0.08635370526462793
# ...                  ...
# 3996  0.0868203486315906
# 3997 0.08682046551257372
# 3998 0.08682058239355683
# 3999 0.08682069927453995
# 4000 0.08682081615552306
#
# [4001 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(data_cp['Frame'], data_cp['Value'], 'ro', alpha=0.35)
# ax.set_xlim(3300, 3700)
ax.set_xlabel('Frames')
# Out:
# Text(0.5, 0, 'Frames')

# %% [markdown]
# ## *Data smoothing*

# %%
# from scipy.signal import savgol_filter

# x = data_cp['Frame']
# y = data_cp['Value']
# y_filtered = savgol_filter(y, 10, 3)

# %%
# plt.figure(figsize=(10,5))
# plt.scatter(x, y_filtered, c='r', marker='o', alpha=0.3)
# # plt.xlim(3300, 3700)

# %% [markdown]
# ## Normalisasi

# %%
# data_cp['y_scaled'] = y_filtered/(y_filtered.std()*2)

data_cp['y_scaled'] = data_cp['Value']/(data_cp['Value'].std()*2)


fig, ax = plt.subplots(figsize=(10,5))

ax.plot(data_cp['Frame'], data_cp['y_scaled'], 'ro', alpha=0.35)
ax.set_xlabel('Frames')
# Out:
# Text(0.5, 0, 'Frames')

# %%
# tulis ke dalam file csv yang baru
data_cp.to_csv('lc_hd150366.csv', header=False, columns=['JD', 'y_scaled'], index=False, sep='\t')

# %%
data_cp
# Out:
#       Frame                       Time    Value                 JD  \
# 0    5000.0 2022-08-09 14:04:20.919734 420288.0 2459801.0863532377
# 1    5001.0 2022-08-09 14:04:20.929834 464140.0 2459801.0863533546
# 2    5002.0 2022-08-09 14:04:20.939934 492350.0 2459801.0863534715
# 3    5003.0 2022-08-09 14:04:20.950033 397106.0 2459801.0863535884
# 4    5004.0 2022-08-09 14:04:20.960133 380007.0 2459801.0863537053
# ...     ...                        ...      ...                ...
# 3996 8996.0 2022-08-09 14:05:01.278121   -806.0 2459801.0868203486
# 3997 8997.0 2022-08-09 14:05:01.288221  -6263.0 2459801.0868204655
# 3998 8998.0 2022-08-09 14:05:01.298321   4697.0 2459801.0868205824
# 3999 8999.0 2022-08-09 14:05:01.308420  -4485.0 2459801.0868206993
# 4000 9000.0 2022-08-09 14:05:01.318520   4060.0  2459801.086820816
#
#                  frac_JD               y_scaled
# 0    0.08635323774069548     1.1064735901058553
# 1    0.08635335462167859     1.2219208069507854
# 2     0.0863534715026617     1.2961880236614367
# 3    0.08635358838364482     1.0454433661502964
# 4    0.08635370526462793     1.0004275866914016
# ...                  ...                    ...
# 3996  0.0868203486315906 -0.0021219204774471775
# 3997 0.08682046551257372  -0.016488322518922672
# 3998 0.08682058239355683     0.0123655837252722
# 3999 0.08682069927453995   -0.01180746072127865
# 4000 0.08682081615552306   0.010688582057612334
#
# [4001 rows x 6 columns]

# %% [markdown]
# ## Kurva cahaya untuk `SORA`

# %%
lc = LightCurve(name='HD 150366', file='lc_hd150366.csv', exptime=0.01)

print(lc)
# Out:
# Light curve name: HD 150366
# Initial time: 2022-08-09 14:04:20.920 UTC
# End time:     2022-08-09 14:05:01.319 UTC
# Duration:     0.673 minutes
# Time offset:  0.000 seconds
#
# Exposure time:    0.0100 seconds
# Cycle time:       0.0101 seconds
# Num. data points: 4001
#
#
# There is no occultation associated with this light curve.
#
# Object LightCurve model was not fitted.
#
# Immersion and emersion times were not fitted or instantiated.

# %%
plt.figure(figsize=(12,5))
lc.plot_lc()
# plt.xlim(46628,46633)

# %%
plt.figure(figsize=(12,5))
tes = lc.occ_detect(plot=True)
tes
# Out:
# {'rank': 1,
#  'occultation_duration': 20.131393522024155,
#  'central_time': 50691.24306254089,
#  'immersion_time': 50681.17736577988,
#  'emersion_time': 50701.3087593019,
#  'time_err': 0.005049258470535278,
#  'depth': 0.9841944708086581,
#  'depth_err': 0.024941600060172514,
#  'baseline': 0.950900431006534,
#  'baseline_err': 0.1220657611428692,
#  'snr': 39.45995719738322,
#  'occ_mask': array([False, False, False, ...,  True,  True, False])}

# %% [markdown]
# ## Pembuatan model
#
# Model kurva cahaya okultasi oleh `SORA` memerlukan beberapa input:
#  - Kecepatan bayangan saat *event*, dalam km/s
#  - Jarak obyek, dalam AU
#  - $\lambda$ pusat dan $\Delta \lambda$ (atau *bandwidth*), dalam mikron
#  - Proyeksi diameter bintang pada jarak obyek, dalam km

# %% [markdown]
# ### A. Jarak obyek penutup saat pengamatan
#
# Untuk okultasi Bulan, obyek penutup adalah Bulan. Pengamatan dilakukan pada tanggal **7 Agustus 2022 pukul 14:04:41.3 UT**. Ephemeris diambil dari https://ssd.jpl.nasa.gov/ftp/eph/planets/ascii/.

# %%
# load timescale dan tampilkan waktu saat ini
ts = load.timescale()

# custom waktu untuk yyyy, mm, dd, hh, mm, ss
t = ts.utc(2022, 8, 7, 14, 4, 41.3)

# %%
# Load the JPL ephemeris DE430 (covers 1549-2650) dan cari jarak Bumi-Bulan
planets = load('de430.bsp')
earth, moon = planets['earth'], planets['moon']

# %%
# posisi Bulan dari Bumi
astrometric = earth.at(t).observe(moon)
ra, dec, distance = astrometric.radec()

# %%
# tampilkan koordinat Bulan dan jarak Bulan dalam AU
print(ra)
print(dec)
print(distance.au)
# Out:
# 16h 42m 19.86s
# -24deg 19' 50.5"
# 0.0024542403847135396

# %%
d_moon = distance.au
d_moon
# Out:
# 0.0024542403847135396

# %%
lc.set_dist(dist=d_moon)

lc.dist
# Out:
# 0.0024542403847135396

# %% [markdown]
# ### B. Nilai $\lambda_0$ dan *bandwidth* $\Delta \lambda$

# %%
lc.set_filter(central_bandpass=0.55, delta_bandpass=0.2)

print('Observational wavelength centred at {:1.3f} with a bandwidth of {:1.3f} microns'
      .format(lc.central_bandpass,lc.delta_bandpass))
# Out:
# Observational wavelength centred at 0.550 with a bandwidth of 0.200 microns

# %% [markdown]
# ### C. Proyeksi diameter bintang pada jarak obyek penutup

# %%
lc.fresnel_scale
# Out:
# 0.010006226559671993

# %%
from sora import Star
from sora.star import kervella, van_belle

# %%
star = Star(coord='16 41 36.2 -24 28  5')
# Out:
# Downloading star parameters from I/350/gaiaedr3
# 1 Gaia-EDR3 star found G=6.030447
# star coordinate at J2016.0: RA=16h41m36.11219s +/- 0.0292 mas, DEC=-24d28m04.8000s +/- 0.0169 mas
#
# Downloading star parameters from I/297/out

# %%
star.mag
# Out:
# {'G': 6.030447,
#  'B': 6.269999980926514,
#  'V': 6.067999839782715,
#  'R': 5.949999809265137,
#  'J': 5.620999813079834,
#  'H': 5.540999889373779,
#  'K': 5.458000183105469}

# %%
from sora import Observer

bosscha = Observer(name='Bosscha Observatory', code='299')

pos = star.get_position(time='2022-08-07 14:04:41.3', observer=bosscha)
print(pos.to_string('hmsdms', precision=10))
# Out:
# WARNING: AstropyDeprecationWarning: ``id_type``s 'majorbody' and 'id' are deprecated and replaced with ``None``, which has the same functionality. [astroquery.jplhorizons.core]
# 16h41m36.0842856428s -24d28m04.8569108569s

# %%
star.error_at(time='2022-08-07 14:04:41.3')
# Out:
# (<Quantity 0.24624921 mas>, <Quantity 0.17805092 mas>)

# %%
diameter = star.apparent_diameter(distance=d_moon)

diameter
# Out:
# Apparent diameter using Kervella et al. (2004)
# <Quantity 0.00052707 km>

# %%
diameter.value
# Out:
# 0.000527074875089087

# %%
lc.set_star_diam(d_star=diameter.value)

# %% [markdown]
# ### D. Kecepatan bayangan Bulan di Bumi
#
# Bulan bergerak relatif terhadap bintang latar belakang dengan kecepatan 0.55 arcsec/s. Ubah nilai ini ke dalam km/s. kalikan angka ini dengan $\sin \theta$ di mana $\theta$ adalah sudut kontak (*contact angle*, CA). Pada pekerjaan ini, nilai kecepatan bayangan diambil dari perangkat lunak `OCCULT v4`

# %%
from astropy.coordinates import Angle
# ang_vel = 0.55*u.arcsec # dalam arcsec/s

# lin_vel = distance.km * np.tan(ang_vel)

kms = u.km/u.s
lin_vel = 0.6384*kms # dari Occult v4

lin_vel
# Out:
# <Quantity 0.6384 km / s>

# %%
lc.set_vel(vel=lin_vel.value)

# %%
plt.figure(figsize=(12,5))
tes2 = lc.occ_detect(plot=True)

tes2
# Out:
# {'rank': 1,
#  'occultation_duration': 20.131393522024155,
#  'central_time': 50691.24306254089,
#  'immersion_time': 50681.17736577988,
#  'emersion_time': 50701.3087593019,
#  'time_err': 0.005049258470535278,
#  'depth': 0.9841944708086581,
#  'depth_err': 0.024941600060172514,
#  'baseline': 0.950900431006534,
#  'baseline_err': 0.1220657611428692,
#  'snr': 39.45995719738322,
#  'occ_mask': array([False, False, False, ...,  True,  True, False])}

# %% [markdown]
# **Parameter untuk model**

# %%
immersion_time = 50681.18  # seconds relative to tref
emersion_time  = 50695  # seconds relative to tref
opacity = 1.0            # 1.0 == opaque; 0.0 == transparent

tmin = immersion_time  - 5 # seconds relative to tref
tmax = emersion_time   + 5 # seconds relative to tref

mask = (lc.time > tmin) & (lc.time < tmax)

# %%
plt.figure(figsize=(12,5))
plt.plot(lc.time,lc.flux,'k.-',zorder=1,label='Observation')
plt.plot(lc.time[mask],lc.flux[mask],'bo',zorder=0,label='Points inside the mask')
plt.axvline(immersion_time,color='r',linestyle='-',label='Immersion')
plt.axvline(emersion_time,color='r',linestyle='--',label='Emersion')
plt.legend()

# %%
lc_chi2 = lc.occ_lcfit(loop=1000)
# Out:
# LightCurve fit: |████████████████████████████████████████|  - 100%

# %%
print(lc_chi2)
# Out:
# Minimum chi-square: 2409.962
# Number of fitted points: 4001
# Number of fitted parameters: 2
# Minimum chi-square per degree of freedom: 0.603
#
# immersion:
#     1-sigma: 50681.181 +/- 0.001
#     3-sigma: 50681.181 +/- 0.004
#
# emersion:
#     1-sigma: 50701.328 +/- 0.004
#     3-sigma: 50701.325 +/- 0.008

# %%
lc_chi2.plot_chi2()

# %%
plt.figure(figsize=(12,5))
lc.occ_model(immersion_time, emersion_time, opacity, mask)

lc.plot_lc()
plt.xlim(50680,50682)
# plt.ylim(-0.5,3)
# Out:
# (50680.0, 50682.0)

# %% [markdown]
# Karena pada pengamatan ini tidak mengalami *emmersion*, maka plot *immersion* saja.

# %%
plt.figure(figsize=(12,5))
plt.plot(lc.time,lc.flux,'k.-',zorder=1,label='Observation')
plt.plot(lc.time[mask],lc.flux[mask],'bo',zorder=0,label='Points inside the mask')
plt.axvline(immersion_time, color='r',linestyle='-',label='Immersion')
plt.legend()

# %%
lc_chi2_imm = lc.occ_lcfit(tmin=tmin, tmax=tmax, immersion_time=immersion_time, loop=1000)
# Out:
# LightCurve fit: |████████████████████████████████████████|  - 100%

# %%
print(lc_chi2_imm)
# Out:
# Minimum chi-square: 982.565
# Number of fitted points: 2359
# Number of fitted parameters: 1
# Minimum chi-square per degree of freedom: 0.417
#
# immersion:
#     1-sigma: 50681.181 +/- 0.001
#     3-sigma: 50681.181 +/- 0.004

# %%
plt.figure(figsize=(12,5))
lc_chi2_imm.plot_chi2()

# %%
print(lc)
# Out:
# Light curve name: HD 150366
# Initial time: 2022-08-09 14:04:20.920 UTC
# End time:     2022-08-09 14:05:01.319 UTC
# Duration:     0.673 minutes
# Time offset:  0.000 seconds
#
# Exposure time:    0.0100 seconds
# Cycle time:       0.0101 seconds
# Num. data points: 4001
#
# Bandpass:             0.550 +/- 0.200 microns
# Object Distance:      0.00 AU
# Used shadow velocity: 0.638 km/s
# Fresnel scale:        0.016 seconds or 0.01 km
# Stellar size effect:  0.001 seconds or 0.00 km
# Inst. response:       0.010 seconds or 0.01 km
# Dead time effect:     0.000 seconds or 0.00 km
# Model resolution:     0.001 seconds or 0.00 km
# Modelled baseflux:    0.951
# Modelled bottomflux:  0.016
# Light curve sigma:    0.110
#
# Immersion time: 2022-08-09 14:04:41.181 UTC +/- 0.001 seconds
# Emersion time:  2022-08-09 14:05:01.328 UTC +/- 0.004 seconds
#
# Monte Carlo chi square fit.
#
# Minimum chi-square: 982.565
# Number of fitted points: 2359
# Number of fitted parameters: 1
# Minimum chi-square per degree of freedom: 0.417
#
# immersion:
#     1-sigma: 50681.181 +/- 0.001
#     3-sigma: 50681.181 +/- 0.004

# %%
plt.figure(figsize=(12,5))
lc.plot_lc()
plt.xlim(50680.75, 50681.75)
# Out:
# (50680.75, 50681.75)

# %%
plt.figure(figsize=(14,6))
lc.plot_lc()
lc.plot_model()

plt.xlim(50680.75, 50681.75)
# plt.ylim(-0.25, 1.5)
# Out:
# (50680.75, 50681.75)

# %%
lc.immersion
# Out:
# <Time object: scale='utc' format='iso' value=2022-08-09 14:04:41.181>
